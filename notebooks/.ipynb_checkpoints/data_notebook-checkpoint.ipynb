# %%
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
columns = ["Date",
           "ApparentPower",
           "CurrentAC_L1", "CurrentAC_L2", "CurrentAC_L3",
           "CurrentDC_MPP1",
           "Energy",
           "VoltageAC_L1", "VoltageAC_L1L2", "VoltageAC_L2", "VoltageAC_L3", "VoltageDC_MPP1",
           "Consumed_Directly", "Consumption",
           "Energy_From_Battery", "Energy_From_Grid",
           "Energy_To_Battery", "Energy_To_Grid",
           "PV_Production"]


def load_cleaned_data():
    path_nan_rows = "CononsythFarm/Raw_data/15minutes_Full/raw_data_without_nan_rows.xlsx"
    if not os.path.exists(path_nan_rows):
        path_empty_columns = "CononsythFarm/Raw_data/15minutes_Full/raw_data_without_empty_columns.xlsx"
        if not os.path.exists(path_empty_columns):
            path = "CononsythFarm/Raw_data/15minutes_Full/full_raw_data.xlsx"
            if not os.path.exists(path):
                print(get_current_time(), "- Creating full raw dataset...")
                data = load_datasets_15mnts()
                print(get_current_time(), "- Done!")
            else:
                print(get_current_time(), "- Loading raw dataset exists on disk...\nLoading...")
                data = pd.read_excel(io=path,
                                     names=columns)
                print(get_current_time(), "- Loaded!")

            print(get_current_time(), "- Removing columns with all values NaN...")
            data = remove_empty_columns(data)
            print(get_current_time(), "- Done!")
        else:
            print(get_current_time(), "- Dataset without empty columns exists on disk...\nLoading...")
            data = pd.read_excel(io=path_empty_columns)
            print(get_current_time(), "- Loaded!")
        print(get_current_time(), "- Removing rows with all values NaN...")
        data = remove_empty_rows(data)
        print(get_current_time(), "- Done!")
    else:
        print(get_current_time(), "- Loading dataset without empty rows exists on disk...")
        data = pd.read_excel(io=path_nan_rows)
        print(get_current_time(), "- Loaded!")

    return remove_zeros_rows(remove_nan_rows(data))


def load_datasets_15mnts():
    data_files = os.listdir("CononsythFarm/Raw_data/North_Mains_Solar_15minutes")
    list_data = []

    for file in data_files:
        path = "CononsythFarm/Raw_data/North_Mains_Solar_15minutes/" + file
        data = pd.read_excel(io=path,
                             skiprows=2,
                             names=columns)
        list_data.append(data)

    full_data = pd.DataFrame(columns=columns)

    for dataset in list_data:
        full_data = full_data.append(dataset)

    full_data.to_excel('CononsythFarm/Raw_data/15minutes_full/full_raw_data.xlsx',
                       index=False)
    return full_data


def remove_empty_columns(dataset):
    columns_aux = columns[1:]
    columns_to_drop = []

    for column in columns_aux:
        uniques_values = dataset[column].unique()
        if len(uniques_values) < 3:
            columns_to_drop.append(column)

    dataset = dataset.drop(columns=columns_to_drop)
    dataset.to_excel('CononsythFarm/Raw_data/15minutes_Full/raw_data_without_empty_columns.xlsx',
                     index=False)
    return dataset


def remove_empty_rows(dataset):
    new_dataset = dataset.dropna(how='all',
                                 subset=dataset.columns[1:])
    new_dataset.to_excel('CononsythFarm/Raw_data/15minutes_Full/raw_data_without_nan_rows.xlsx',
                         index=False)

    return new_dataset


def remove_nan_rows(dataset):
    return dataset.dropna(how='any')


def remove_zeros_rows(dataset):
    return dataset.loc[(dataset[dataset.columns[1:]] != 0).all(axis=1)]


def get_current_time():
    now = datetime.now()
    dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
    return f'[{dt_string}]'


def soft_data_per_day(dataset):
    return dataset

# %%
data = load_cleaned_data()
data.head()
# Out:
# [21/07/2021 11:29:43] - Creating full raw dataset...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e772c004f8b7> in <module>
# ----> 1 data = load_cleaned_data()
#       2 data.head()
#
# <ipython-input-4-e0c4e825157f> in load_cleaned_data()
#      19             if not os.path.exists(path):
#      20                 print(get_current_time(), "- Creating full raw dataset...")
# ---> 21                 data = load_datasets_15mnts()
#      22                 print(get_current_time(), "- Done!")
#      23             else:
#
# <ipython-input-4-e0c4e825157f> in load_datasets_15mnts()
#      46
#      47 def load_datasets_15mnts():
# ---> 48     data_files = os.listdir("./CononsythFarm/Raw_data/North_Mains_Solar_15minutes")
#      49     list_data = []
#      50
#
# FileNotFoundError: [WinError 3] El sistema no puede encontrar la ruta especificada: './CononsythFarm/Raw_data/North_Mains_Solar_15minutes'

# %%
data.describe()

# %% [markdown]
# # 2 - EDA: Exploratory Data Analysis

# %%
data.info()

# %% [markdown]
# ## 2.1 - Plotting Time Series

# %%
data_datetime = data.set_index(data['Date'])
data_datetime = data_datetime.sort_index() 

for i in range(1, data_datetime.shape[1]):
        plt.figure(figsize=(20,3))
        plt.title(data_datetime.columns[i])
        plt.plot(data_datetime[data_datetime.columns[i]])
        plt.show()

# %%
data_datetime_outliers = data_datetime.loc[data_datetime['VoltageAC_L1'] > 400]
data_datetime_outliers
# Out:
#                                    Date  ApparentPower  CurrentAC_L1  \
# Date
# 2015-05-25 17:45:00 2015-05-25 17:45:00        17234.0         22.93
# 2017-11-09 11:30:00 2017-11-09 11:30:00        26252.0         35.52
#
#                      CurrentAC_L2  CurrentAC_L3  CurrentDC_MPP1   Energy  \
# Date
# 2015-05-25 17:45:00         23.92         24.52           33.31  2901.70
# 2017-11-09 11:30:00         38.93         32.59           34.70  2561.81
#
#                      VoltageAC_L1  VoltageAC_L1L2  VoltageAC_L2  VoltageAC_L3  \
# Date
# 2015-05-25 17:45:00         479.0           837.0         483.0         482.0
# 2017-11-09 11:30:00         489.0           848.0         489.0         484.0
#
#                      VoltageDC_MPP1  PV_Production
# Date
# 2015-05-25 17:45:00           302.3        2901.70
# 2017-11-09 11:30:00           300.0        2561.81

# %% [markdown]
# ## 2.2 - Univariate Analysis

# %%
def make_analysis(dataset, column, alpha=0.05, qq_plot=True, histogram=False, density=False):    
    if density:
        print(get_current_time(), "- Plotting distribution of", column, "column...")
        dataset[column].plot.kde()
        plt.show()
          
    if histogram:
        print(get_current_time(), "- Plotting Histogram of", column, "column...")
        plt.hist(dataset[column])
        plt.show()

    if qq_plot:
        print(get_current_time(), "- Plotting QQPlot of", column, "column...")
        qqplot(dataset[column], line='s')
        plt.show()

# %% [markdown]
# ## 2.3 - Correlation Matrix

# %%
corr = data_datetime.corr()

mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
# Out:
# <style  type="text/css" >
# #T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row0_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col9,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col10,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col11,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col11{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row1_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row2_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row3_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row4_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row5_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col6,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col7,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col8,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col4{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col0{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col6{
#             background-color:  #f7ad90;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row6_col4{
#             background-color:  #f7a98b;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col0{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row7_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col4,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col7{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col3,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col9{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row8_col5,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row11_col8{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col4{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col2,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row9_col3{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col0,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col1,#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col3{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col2{
#             background-color:  #f6bea4;
#             color:  #000000;
#         }#T_aad50b99_e4bf_11eb_b2d8_98fa9b311cb5row10_col4{
#             background-c

# %%
data_datetime_outliers = data_datetime.loc[data_datetime['VoltageAC_L1'] < 400]

# %%
x_values = [(col, data_datetime_outliers[col]) for col in data_datetime.columns[1:]]
y = data_datetime_outliers['PV_Production']

# %%
fig, axs = plt.subplots(3, 4, figsize=(15, 8))
fig.tight_layout(pad=4.0)

fig.suptitle('Correlation Plots vs PV_Production')

cont = 0
for row in range(0, 3):
    for column in range(0, 4):
        axs[row, column].scatter(x_values[cont][1], y)
        axs[row, column].set_title(x_values[cont][0])
        cont+=1

# %% [markdown]
# Vemos que la relacción entre las variables *Energy* y *PV_Production* es totalmente lineal. Esto se debe a que son la misma varaible con distinto nombre, por lo que habrá que eliminarla durante la fase de entrenamiento.

# %%
data_datetime
# Out:
#                                    Date  ApparentPower  CurrentAC_L1  \
# Date
# 2011-09-30 12:00:00 2011-09-30 12:00:00        26177.0         35.36
# 2011-09-30 12:15:00 2011-09-30 12:15:00        27404.0         37.54
# 2011-09-30 13:45:00 2011-09-30 13:45:00        19097.0         25.37
# 2011-09-30 14:00:00 2011-09-30 14:00:00        23531.0         31.69
# 2011-09-30 14:15:00 2011-09-30 14:15:00        24706.0         33.36
# ...                                 ...            ...           ...
# 2017-12-31 14:45:00 2017-12-31 14:45:00         3304.0          4.48
# 2017-12-31 15:00:00 2017-12-31 15:00:00         2183.0          2.92
# 2017-12-31 15:15:00 2017-12-31 15:15:00          909.0          1.20
# 2017-12-31 15:30:00 2017-12-31 15:30:00          391.0          0.45
# 2017-12-31 15:45:00 2017-12-31 15:45:00          138.0          0.12
#
#                      CurrentAC_L2  CurrentAC_L3  CurrentDC_MPP1   Energy  \
# Date
# 2011-09-30 12:00:00         36.06         35.74           98.68  5269.04
# 2011-09-30 12:15:00         37.72         37.60          104.88  7011.75
# 2011-09-30 13:45:00         25.92         25.97           72.06  3563.88
# 2011-09-30 14:00:00         31.75         31.67           90.23  5971.99
# 2011-09-30 14:15:00         33.56         33.54           94.58  6314.80
# ...                           ...           ...             ...      ...
# 2017-12-31 14:45:00          4.62          4.54           11.93   840.13
# 2017-12-31 15:00:00          3.09          3.02            8.45   555.34
# 2017-12-31 15:15:00          1.30          1.22            4.55   229.53
# 2017-12-31 15:30:00          0.60          0.54            3.64    96.82
# 2017-12-31 15:45:00          0.29          0.15            3.89    15.80
#
#                      VoltageAC_L1  VoltageAC_L1L2  VoltageAC_L2  VoltageAC_L3  \
# Date
# 2011-09-30 12:00:00         243.0           422.0         244.0         243.0
# 2011-09-30 12:15:00         242.0           419.0         243.0         242.0
# 2011-09-30 13:45:00         246.0           427.0         247.0         246.0
# 2011-09-30 14:00:00         246.0           428.0         247.0         247.0
# 2011-09-30 14:15:00         245.0           425.0         246.0         245.0
# ...                           ...             ...           ...           ...
# 2017-12-31 14:45:00         241.0           418.0         242.0         242.0
# 2017-12-31 15:00:00         240.0           417.0         241.0         241.0
# 2017-12-31 15:15:00         242.0           419.0         244.0         243.0
# 2017-12-31 15:30:00         242.0           419.0         243.0         243.0
# 2017-12-31 15:45:00         241.0           418.0         243.0         242.0
#
#                      VoltageDC_MPP1  PV_Production
# Date
# 2011-09-30 12:00:00           294.0        5269.04
# 2011-09-30 12:15:00           275.0        7011.75
# 2011-09-30 13:45:00           296.0        3563.88
# 2011-09-30 14:00:00           275.0        5971.99
# 2011-09-30 14:15:00           276.0        6314.80
# ...                             ...            ...
# 2017-12-31 14:45:00           302.0         840.13
# 2017-12-31 15:00:00           292.0         555.34
# 2017-12-31 15:15:00           279.0         229.53
# 2017-12-31 15:30:00           266.0          96.82
# 2017-12-31 15:45:00           238.0          15.80
#
# [109449 rows x 13 columns]

# %%
data_datetime = data_datetime.drop(columns=['Energy'])

# %% [markdown]
# # Modelos Estado del Arte

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedKFold
from sklearn.neural_network import MLPRegressor

# %%
X = ["ApparentPower",
     "CurrentAC_L1", "CurrentAC_L2", "CurrentAC_L3",
     "CurrentDC_MPP1",
     "VoltageAC_L1", "VoltageAC_L1L2", "VoltageAC_L2", "VoltageAC_L3", "VoltageDC_MPP1"]

y = ["PV_Production"]

# %%
scaler = StandardScaler()
scaler.fit(data_datetime[X].values)

df_train_esc = scaler.transform(data_datetime[X].values)

print(df_train_esc.shape)
# Out:
# (109449, 10)

# %%
# Función que obtiene el MAE, RMSE y R2 de VC con repetición
def entrena_model(model, num_folds=10, num_bags=10):
    np.random.seed(2021)
    X_tot = df_train_esc.copy()
    y_tot = data_datetime[y].values.reshape(-1)

    
    # Creamos arrays para las predicciones
    preds_val = np.empty((len(X_tot),num_bags))
    preds_val[:] = np.nan
    
    # Entrena y extrae la predicciones con validación cruzada repetida
    folds = RepeatedKFold(n_splits=num_folds, n_repeats=num_bags, random_state=2021)  
    
    for niter, (train_index, val_index) in enumerate(folds.split(X_tot, y_tot)):
        nbag = niter//num_folds #Extrae el número de repetición (bag)
        X_train, X_val = X_tot[train_index], X_tot[val_index]
        y_train, y_val = y_tot[train_index], y_tot[val_index]
        model.fit(X_train, y_train)
        preds_val[val_index,nbag] = model.predict(X_val)
        
    # Promedia las predicciones
    preds_val_mean = preds_val.mean(axis=1) 
    
    # Extrae las métricas
    mae_val = mean_absolute_error(y_tot, preds_val_mean) 
    rmse_val = np.sqrt(mean_squared_error(y_tot, preds_val_mean))
    r2_val = r2_score(y_tot, preds_val_mean)
    
    return mae_val, rmse_val, r2_val

# %% [markdown]
# ## Regresión Lineal

# %%
modelo_base = Ridge()
mae_val, rmse_val, r2_val = entrena_model(modelo_base)

print(get_current_time(), 
      '- RIDGE -> Val:[MAE={:.3f}, RMSE={:,.3f}, R2={:,.3f}]'.format(mae_val, rmse_val, r2_val))

rmse_minimo = rmse_val
alpha_minimo = 1.0
solver_minimo = 'auto'

print("")
print(get_current_time(), "Trying to improve base model...\n")

for alpha in np.arange(0, 10, 0.5):
    model = Ridge(alpha=alpha)
    mae_val, rmse_val, r2_val = entrena_model(model)
    if rmse_val < rmse_minimo:
        alpha_minimo = alpha
        rmse_minimo = rmse_val
        print(get_current_time(), 
              'RIDGE con alpha={} -> Val:[MAE={:.3f}, RMSE={:,.3f}, R2={:,.3f}]'.format(alpha,
                                                                 mae_val, rmse_val, r2_val))
print("")
print(get_current_time(),"Ended of greedy search...\n")
# Out:
# [14/07/2021 16:14:22] - RIDGE -> Val:[MAE=155.632, RMSE=354.717, R2=0.980]
#
# [14/07/2021 16:14:22] Trying to improve base model...
#
# [14/07/2021 16:14:23] RIDGE con alpha=0.0 -> Val:[MAE=155.493, RMSE=354.716, R2=0.980]
# [14/07/2021 16:14:25] RIDGE con alpha=0.5 -> Val:[MAE=155.563, RMSE=354.715, R2=0.980]
#
# [14/07/2021 16:15:03] Ended of greedy search...

# %% [markdown]
# ## KNN

# %%
modelo_base = KNeighborsRegressor(n_jobs=8)
mae_val, rmse_val, r2_val = entrena_model(modelo_base)
                                          
print('KNN -> Val:[MAE={:.3f}, RMSE={:,.3f}, R2={:,.3f}]'.format(mae_val, rmse_val, r2_val))

n_vecinos_minimo = 5
pesos_minimo = 'uniform'
rmse_minimo = rmse_val

print("")
print(get_current_time(), "Trying to improve base model...\n")

for n_vecinos in np.arange(1,35, 1):
    for weight in ['uniform', 'distance']:
        model = KNeighborsRegressor(n_neighbors=n_vecinos, weights=weight, n_jobs=8)
        mae_val, rmse_val, r2_val = entrena_model(model)
        if rmse_val-rmse_minimo < 0:
            n_vecinos_minimo = n_vecinos
            rmse_minimo = rmse_val
            pesos_minimo = weight
            print('KNN(n_neighbors={}, weights={}) -> Val:[MAE={:.3f}, RMSE={:,.3f}, R2={:,.3f}]'.format(n_vecinos, weight,
                mae_val, rmse_val, r2_val))
            
print("")
print(get_current_time(),"Ended of greedy search...\n")
# Out:
# KNN -> Val:[MAE=65.196, RMSE=182.679, R2=0.995]
#
# [14/07/2021 16:34:33] Trying to improve base model...
#
# KNN(n_neighbors=4, weights=distance) -> Val:[MAE=64.662, RMSE=180.052, R2=0.995]
# KNN(n_neighbors=5, weights=distance) -> Val:[MAE=63.275, RMSE=178.946, R2=0.995]
# KNN(n_neighbors=6, weights=distance) -> Val:[MAE=62.305, RMSE=178.087, R2=0.995]
# KNN(n_neighbors=7, weights=distance) -> Val:[MAE=61.674, RMSE=177.840, R2=0.995]
# KNN(n_neighbors=8, weights=distance) -> Val:[MAE=61.296, RMSE=177.813, R2=0.995]
#
# [14/07/2021 17:39:47] Ended of greedy search...

# %% [markdown]
# ## ANN

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
modelo_base = MLPRegressor()
mae_val, rmse_val, r2_val = entrena_model(modelo_base)

num_neuronas = 100
activacion = 'relu'
solver = 'adam'

print('ANN(hidden_layer_sizes=({},), activation={}, solver={}) -> Val:[MAE={:.3f},RMSE={:,.3f},R2={:,.3f}]'.format(num_neuronas, activacion, solver,
                                                                              mae_val, rmse_val, r2_val))

num_capas = 100
pesos_minimo = 'uniform'
rmse_minimo = rmse_val

print("")
print(get_current_time(), "Trying to improve base model...\n")

for solver in ['adam', 'lbfgs']:
    for activacion in ['relu', 'logistic']:
        for num_neuronas in np.arange(1, 500, 10):
            model =  MLPRegressor(hidden_layer_sizes=(num_neuronas,),
                                  solver=solver,
                                  activation=activacion)

            mae_val, rmse_val, r2_val = entrena_model(model)

            print('ANN(hidden_layer_sizes=({},), activation={}, solver={}) -> Val:[MAE={:.3f},RMSE={:,.3f},R2={:,.3f}]'.format(num_neuronas, activacion,
                                                                                  solver, mae_val, rmse_val, r2_val))
        
print("")
print(get_current_time(),"Ended of greedy search...\n")
